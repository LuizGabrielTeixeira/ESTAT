# %%
# ex-1
import pandas as pd
import numpy as np

path = "../data/Cap2_Exercicio1.csv"
df = pd.read_csv(path)

df['relative_freq'] = df['freq'] / df['freq'].sum() * 100

# input hard coded values bc the csv file has only 10 rows
lower_lim = 0
upper_lim = 15
num_classes = 10

amplitude = upper_lim - lower_lim

# generate an array with all the midpoints: [7.5, 22.5, 37.5, ...]
midpoints = lower_lim + amplitude / 2 + np.arange(classes) * amplitude

df['midpoints'] = midpoints

mean_months = (df['midpoints'] * df['relative_freq']).sum() / 100

print(f'The mean number of months is: {mean_months:.1f}\n')
print(df)
# Out:
# The mean number of months is: 43.0
#
#    freq  relative_freq  midpoints
# 0     9       8.653846        7.5
# 1    35      33.653846       22.5
# 2    20      19.230769       37.5
# 3    20      19.230769       52.5
# 4     7       6.730769       67.5
# 5     4       3.846154       82.5
# 6     5       4.807692       97.5
# 7     1       0.961538      112.5
# 8     1       0.961538      127.5
# 9     2       1.923077      142.5

# %%
# ex-2
